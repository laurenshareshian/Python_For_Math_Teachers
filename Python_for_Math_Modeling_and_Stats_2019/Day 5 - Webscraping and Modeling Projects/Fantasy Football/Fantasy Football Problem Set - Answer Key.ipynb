# %% [markdown]
# In this lesson, you will investigate how well ESPN does at predicting NFL fantasy football player performance. First, import these modules.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1.) We are interested in how well ESPN does at predicting how well a player will do in fantasy football.
#
# The ESPN website from 2017 listed how many fantasy points each player had ACTUALLY scored by the end of the season. The website used to be here:
#
# http://games.espn.com/ffl/leaders
#
# and every tab had the pattern http://games.espn.com/ffl/leaders?startIndex=0, http://games.espn.com/ffl/leaders?startIndex=50, ..., http://games.espn.com/ffl/leaders?startIndex=850 , where each page contained 50 more players' info.
#
# We have saved these webpages locally, and they are called "fftrankings0.htm", "fftrankings50.htm", ..., "fftrankings850.htm".
#
# Create a list called "urls" containing each of the these fftrankings file names.

# %%
urls = []
for i in range(0,900,50):
    urls.append('data/fftrankings'+str(i)+'.htm')
urls[0]
# Out:
# 'data/fftrankings0.htm'

# %% [markdown]
# 2.We can go to the first url and use pd.read_html to read in the info. "pd.read_html" is an awesome command when it works! It reads tables directly off of websites and saves them to a pandas dataframe. We'll save the dataframe with the name "df". Notice, those, that for some reason reading from the file creates a lot of duplicates. The page is a big buggy when it is saved locally, therefore, once you are done reading in the file, delete all of the duplicates. Google "pandas remove duplicates" to see how to do this in one line.

# %%
import pandas as pd
tables = pd.read_html(urls[0])
df = tables[0]
df.drop_duplicates(subset=None, keep='first', inplace=True)
df.shape
# Out:
# (137, 21)

# %% [markdown]
# 3.There are many columns. Let's only save the player name and points columns. Let's also drop the first three rows which are headers and not player names. "player" and "2017 points."

# %%
df = df[df.columns[[0,20]]]
df = df.rename(columns={0: 'player', 20: '2017 points'})
df.drop(df.index[0:3], inplace = True)
df.head()
# Out:
#                    player 2017 points
# 3  Todd Gurley II, LAR RB       383.3
# 4  Russell Wilson, Sea QB       347.9
# 5    Le'Veon Bell, Pit RB       341.6
# 6     Alvin Kamara, NO RB       320.4
# 7   Antonio Brown, Pit WR       310.3

# %% [markdown]
# 4.Okay. Now we are going to loop through and add the dataframes you get from visiting the other urls to the bottom of the dataframe you got from the first url. You can do this by using the following command within the for loop:
#
# table = pd.concat([table, new_table])
#
# Be sure to drop the first three rows from the new table that you read in each time before you add them to the old table (since they don't contain player names). Also, remove the duplicates. Then, only save the player name and points columns and rename those columns "player" and "2017 points." Finally, concatenate the old table with the new each time. Your final dataframe should have 1008 rows.

# %%
for i in range(1,len(urls)):
    df2 = pd.read_html(urls[i])[0]
    df2.drop_duplicates(subset=None, keep='first', inplace=True)
    df2 = df2[df2.columns[[0,20]]]
    df2 = df2.rename(columns={0: 'player', 20: '2017 points'})
    df2.drop(df2.index[0:3], inplace = True)
    df = pd.concat([df, df2])

print(df.shape)
df.head()
# Out:
# (1008, 2)
#                    player 2017 points
# 3  Todd Gurley II, LAR RB       383.3
# 4  Russell Wilson, Sea QB       347.9
# 5    Le'Veon Bell, Pit RB       341.6
# 6     Alvin Kamara, NO RB       320.4
# 7   Antonio Brown, Pit WR       310.3

# %% [markdown]
# 5.Drop rows that are missing ANY entries. Then, reset the index. Your final dataframe should have 890 rows.

# %%
df = df.dropna(how = 'any')
df = df.reset_index(drop=True)
df.head()
# Out:
#                    player 2017 points
# 0  Todd Gurley II, LAR RB       383.3
# 1  Russell Wilson, Sea QB       347.9
# 2    Le'Veon Bell, Pit RB       341.6
# 3     Alvin Kamara, NO RB       320.4
# 4   Antonio Brown, Pit WR       310.3

# %%
playernames = []
for name in df['player']:
    index = name.split(',')
    player = index[0]
    team = index[1].split()[0].upper()
    playername = player + ', ' + team
    print(playername)
# Out:
# Todd Gurley II, LAR
# Russell Wilson, SEA
# Le'Veon Bell, PIT
# Alvin Kamara, NO
# Antonio Brown, PIT
# DeAndre Hopkins, HOU
# Cam Newton, CAR
# Tom Brady, NE
# Kareem Hunt, KC
# Alex Smith, WSH
# Melvin Gordon, LAC
# Keenan Allen, LAC
# Carson Wentz, PHI
# Mark Ingram, NO
# Kirk Cousins, MIN
# Matthew Stafford, DET
# Philip Rivers, LAC
# LeSean McCoy, BUF
# Drew Brees, NO
# Larry Fitzgerald, ARI
# Ben Roethlisberger, PIT
# Dak Prescott, DAL
# Jarvis Landry, CLE
# Michael Thomas, NO
# Jared Goff, LAR
# Julio Jones, ATL
# Blake Bortles, JAX
# Tyreek Hill, KC
# Adam Thielen, MIN
# Case Keenum, DEN
# Carlos Hyde, CLE
# Travis Kelce, KC
# Leonard Fournette, JAX
# Christian McCaffrey, CAR
# Matt Ryan, ATL
# Rob Gronkowski, NE
# A.J. Green, CIN
# Marvin Jones Jr., DET
# Golden Tate, DET
# Doug Baldwin, SEA
# Tyrod Taylor, CLE
# Davante Adams, GB
# Brandin Cooks, LAR
# Duke Johnson Jr., CLE
# Andy Dalton, CIN
# Marcus Mariota, TEN
# Derek Carr, OAK
# Jacoby Brissett, IND
# Demaryius Thomas, DEN
# Josh McCown, NYJ
# Ezekiel Elliott, DAL
# Mike Evans, TB
# Dion Lewis, TEN
# Zach Ertz, PHI
# Jameis Winston, TB
# Devonta Freeman, ATL
# Robby Anderson, NYJ
# Jordan Howard, CHI
# Stefon Diggs, MIN
# JuJu Smith-Schuster, PIT
# Alshon Jeffery, PHI
# Devin Funchess, CAR
# Lamar Miller, HOU
# Nelson Agholor, PHI
# Eli Manning, NYG
# Dez Bryant, FA
# Joe Flacco, BAL
# Jerick McKinnon, SF
# Cooper Kupp, LAR
# Jermaine Kearse, NYJ
# DeShone Kizer, GB
# T.Y. Hilton, IND
# C.J. Anderson, CAR
# Kenny Stills, MIA
# Delanie Walker, TEN
# Mohamed Sanu, ATL
# Frank Gore, MIA
# Evan Engram, NYG
# Michael Crabtree, BAL
# DeMarco Murray, FA
# Jimmy Graham, GB
# Alex Collins, BAL
# Jack Doyle, IND
# Deshaun Watson, HOU
# Marquise Goodwin, SF
# Tevin Coleman, ATL
# Javorius Allen, BAL
# Marshawn Lynch, OAK
# Robert Woods, LAR
# Jamison Crowder, WSH
# Ted Ginn Jr., NO
# Randall Cobb, GB
# Amari Cooper, OAK
# Kyle Rudolph, MIN
# Jay Cutler, FA
# Latavius Murray, MIN
# Rishard Matthews, TEN
# Theo Riddick, DET
# Giovani Bernard, CIN
# Chris Thompson, WSH
# Mike Wallace, PHI
# Paul Richardson, WSH
# Tarik Cohen, CHI
# Marqise Lee, JAX
# Jason Witten, DAL
# Sammy Watkins, KC
# Bilal Powell, NYJ
# Sterling Shepard, NYG
# Isaiah Crowell, NYJ
# Cameron Brate, TB
# Jamaal Williams, GB
# Kenyan Drake, MIA
# Joe Mixon, CIN
# Danny Amendola, MIA
# DeSean Jackson, TB
# Tyrell Williams, LAC
# Orleans Darkwa, NYG
# Benjamin Watson, NO
# Jordy Nelson, OAK
# Kelvin Benjamin, BUF
# Jay Ajayi, PHI
# Derrick Henry, TEN
# Mitchell Trubisky, CHI
# James White, NE
# Jared Cook, OAK
# Keelan Cole, JAX
# Martavis Bryant, OAK
# Eric Ebron, IND
# Travis Benjamin, LAC
# DeVante Parker, MIA
# Rex Burkhead, NE
# Aaron Rodgers, GB
# Adam Humphries, TB
# Hunter Henry*, LAC
# Kendall Wright, MIN
# Ryan Grant, IND
# Trevor Siemian, MIN
# Brandon LaFell, CIN
# Brett Hundley, GB
# Ameer Abdullah, DET
# Tyler Kroft, CIN
# Tyler Lockett, SEA
# Vernon Davis, WSH
# Matt Forte, NYJ
# Josh Doctson, WSH
# Austin Hooper, ATL
# Jonathan Stewart, NYG
# Charles Clay, BUF
# Eric Decker, FA
# Albert Wilson, MIA
# Emmanuel Sanders, DEN
# Will Fuller V, HOU
# Terrance Williams, DAL
# Chris Hogan, NE
# Samaje Perine, WSH
# LeGarrette Blount, DET
# Austin Ekeler, LAC
# George Kittle, SF
# Deonte Thompson, DAL
# Wayne Gallman, NYG
# Matt Breida, SF
# Marlon Mack, IND
# Jaron Brown, SEA
# Carson Palmer, ARI
# Jeremy Maclin, FA
# Austin Seferian-Jenkins, JAX
# O.J. Howard, TB
# Allen Hurns, DAL
# Jesse James, PIT
# Julius Thomas, MIA
# J.D. McKissic, SEA
# Trent Taylor, SF
# David Njoku, CLE
# Kenny Golladay, DET
# J.J. Nelson, ARI
# Chris Godwin, TB
# Rod Smith, DAL
# Corey Clement, PHI
# Ty Montgomery, GB
# Cole Beasley, DAL
# Devontae Booker, DEN
# Torrey Smith, CAR
# Seth Roberts, OAK
# Pierre Garcon, SF
# Roger Lewis, NYG
# C.J. Beathard, SF
# Jimmy Garoppolo, SF
# Marcedes Lewis, GB
# T.J. Yeldon, JAX
# Andre Ellington, HOU
# Jalen Richard, OAK
# Cordarrelle Patterson, NE
# Peyton Barber, TB
# DeAndre Washington, OAK
# Chris Ivory, BUF
# TJ Jones, DET
# Shane Vereen, FA
# Bennie Fowler III, CHI
# Taylor Gabriel, CHI
# Aaron Jones, GB
# Trey Burton, CHI
# Ed Dickson, SEA
# Antonio Gates, LAC
# Adrian Peterson, FA
# Garrett Celek, SF
# Jermaine Gresham, ARI
# Donte Moncrief, JAX
# Seth DeValve, CLE
# Elijah McGuire, NYJ
# Doug Martin, OAK
# Bruce Ellington, HOU
# Odell Beckham Jr., NYG
# Ryan Fitzpatrick, TB
# Charles Sims, TB
# Brandon Coleman, NO
# Charcandrick West, KC
# Alfred Morris, DAL
# Zay Jones, BUF
# John Brown, BAL
# Kyle Juszczyk, SF
# Corey Davis, TEN
# Mike Gillislee, NE
# Rashard Higgins, CLE
# Joshua Bellamy, CHI
# Brock Osweiler, MIA
# Kerwynn Williams, KC
# Jamaal Charles, FA
# Dede Westbrook, JAX
# Chris Moore, BAL
# Corey Coleman, CLE
# Dalvin Cook, MIN
# Dontrelle Inman, CHI
# Stephen Anderson, HOU
# Brice Butler, ARI
# Nick O'Leary, BUF
# Brian Hoyer, NE
# Coby Fleener, NO
# Ricardo Louis, CLE
# Cody Latimer, NYG
# Blaine Gabbert, TEN
# Tyler Higbee, LAR
# Tavarres King, MIN
# Jordan Reed, WSH
# Justin Hardy, ATL
# Damien Williams, KC
# Rhett Ellison, NYG
# Martellus Bennett, NE
# Danny Woodhead, BAL
# Chester Rogers, IND
# Kenny Britt, NE
# Josh Gordon, CLE
# Jordan Matthews, NE
# Aldrick Robinson, SF
# D'Onta Foreman, HOU
# Benny Cunningham, CHI
# Tyler Boyd, CIN
# Zach Miller*, CHI
# A.J. Derby, MIA
# Luke Willson, DET
# Darren Fells, CLE
# Michael Campanaro, TEN
# Mike Davis, SEA
# Gerald Everett, LAR
# Malcolm Brown, LAR
# Tom Savage, NO
# Mike Tolbert, BUF
# Drew Stanton, CLE
# Nick Boyle, BAL
# Ricky Seals-Jones, ARI
# Terrelle Pryor Sr., NYJ
# Jarius Wright, CAR
# Taywan Taylor, TEN
# Jacquizz Rodgers, TB
# Wendell Smallwood, PHI
# Demetrius Harris, KC
# Geronimo Allison, GB
# Jeremy Kerley, BUF
# Jonnu Smith, TEN
# Russell Shepard, NYG
# Johnny Holton, OAK
# Alfred Blue, HOU
# Mack Hollins, PHI
# Jakeem Grant, MIA
# Lance Kendricks, GB
# Rob Kelley, WSH
# Andre Holmes, BUF
# Tavon Austin, DAL
# Adam Shaheen, CHI
# Demarcus Robinson, KC
# Greg Olsen, CAR
# Corey Grant, JAX
# Kendrick Bourne, SF
# Matt Moore, FA
# Braxton Miller, HOU
# De'Anthony Thomas, KC
# Kapri Bibbs, WSH
# Laquon Treadwell, MIN
# Damiere Byrd, CAR
# Chris Carson, SEA
# Virgil Green, LAC
# Dion Sims, CHI
# Vance McDonald, PIT
# Travaris Cadet, BUF
# Eli Rogers, PIT
# Ryan Griffin, HOU
# Levine Toilolo, DET
# Alex Erickson, CIN
# Jeff Heuerman, DEN
# James O'Shaughnessy, JAX
# T.J. Yates, FA
# Richard Rodgers, PHI
# Nick Foles, PHI
# Kevin Hogan, WSH
# Mike Glennon, ARI
# Brandon Marshall, SEA
# Curtis Samuel, CAR
# D.J. Foster, ARI
# Elijhaa Penny, ARI
# Phillip Dorsett, NE
# Thomas Rawls, NYJ
# Brent Celek, PHI
# Tion Green, DET
# Nick Vannett, SEA
# Troy Niklas, NE
# Josh Hill, NO
# Tommy Bohanon, JAX
# Anthony Fasano, MIA
# Eddie Lacy, FA
# Chris Conley, KC
# Kamar Aiken, IND
# Maxx Williams, BAL
# Terrance West, BAL
# Josh Reynolds, LAR
# Jordan Taylor, DEN
# Tommylee Lewis, NO
# Sam Bradford, ARI
# C.J. Fiedorowicz, HOU
# Louis Murphy, SF
# Eric Tomlinson, NYJ
# Robert Turbin, IND
# Daniel Brown, CHI
# David Morgan, MIN
# Bryce Petty, MIA
# C.J. Uzomah, CIN
# Brandon Williams, IND
# Dwayne Allen, NE
# Pharoh Cooper, LAR
# Niles Paul, JAX
# Tre McBride III, NYJ
# Kenjon Barner, CAR
# Paul Perkins*, NYG
# Jaydon Mickens, JAX
# Kaelin Clay, BUF
# C.J. Ham, MIN
# Brenton Bersin, CAR
# Chris Johnson, ARI
# Anthony Sherman, KC
# Mike Williams, LAC
# Brandon Tate, BUF
# Logan Thomas, BUF
# Jamize Olawale, DAL
# David Fales, MIA
# James Hanna, DAL
# Josh Malone, CIN
# Darren Sproles, PHI
# Chad Hansen, NYJ
# Travis Rudolph, NYG
# Michael Floyd, MIN
# Breshad Perriman, BAL
# Fozzy Whittaker*, CAR
# Kasen Williams, IND
# Jeremy Hill, NE
# Jerell Adams, NYG
# Michael Hoomanawanui, NO
# Clive Walford, NYJ
# C.J. Prosise, SEA
# ArDarius Stewart, NYJ
# Branden Oliver, LAC
# Stevan Ridley, PIT
# Cameron Artis-Payne, CAR
# Maurice Harris, WSH
# Darrius Heyward-Bey, PIT
# Lee Smith, OAK
# Terron Ward, ATL
# Willie Snead, BAL
# Derek Carrier, OAK
# Amara Darboh, SEA
# Paxton Lynch, DEN
# Andy Janovich, DEN
# Freddie Martino, TB
# Ross Travis, IND
# Ryan Switzer, OAK
# Roosevelt Nix, PIT
# James Conner, PIT
# Michael Thomas, LAR
# Neal Sterling, NYJ
# Xavier Grimble, PIT
# EJ Manuel, OAK
# Marvin Hall, ATL
# Phillip Supernaw, TEN
# Leonte Carroo, MIA
# Brian Quick, WSH
# Chris Thompson, HOU
# Trevor Davis, GB
# Aaron Ripkowski, GB
# Luke Stocker, TEN
# Bobby Rainey Jr., BAL
# David Johnson, ARI
# Sammie Coates, HOU
# Tyler Ervin, HOU
# De'Angelo Henderson, DEN
# Jaelen Strong, JAX
# Byron Marshall, WSH
# Justin Hunter, PIT
# Tanner McEvoy, SEA
# Lance Dunbar, LAR
# Brittan Golden, ARI
# Zach Line, NO
# Bryce Treggs, PHI
# Ben Koyack, JAX
# Alan Cross, TB
# Trey Edmunds, NO
# Austin Traylor, DEN
# Nathan Peterman, BUF
# Patrick Mahomes, KC
# Ryan Mallett, FA
# James Develin, NE
# Geno Smith, LAC
# Patrick DiMarco, BUF
# Akeem Hunt*, KC
# Chad Williams, ARI
# Jeremy Sprinkle, WSH
# Brian Hill, CIN
# Jacob Hollister, NE
# Sean McGrath, LAC
# Tyler Eifert, CIN
# Michael Roberts, DET
# Zach Zenner, DET
# Landry Jones, PIT
# Tre Madden, SEA
# Brandon Bolden, NE
# Matthew Dayes, CLE
# Markus Wheaton, PHI
# Michael Clark, GB
# Derek Watt, LAC
# Will Tye, NE
# Dwayne Washington, DET
# Keith Smith, OAK
# Nate Sudfeld, PHI
# Marcus Johnson, SEA
# Jared Abbrederis, DET
# Orson Charles, KC
# Noah Brown, DAL
# Jay Prosch, HOU
# Blake Bell, MIN
# Quan Bray, BUF
# Marcus Murphy, BUF
# Randall Telfer, CLE
# Tanner Gentry, CHI
# Jalston Fowler, SEA
# Griff Whalen, OAK
# Vince Mayle, BAL
# Nick Williams, TEN
# Bernard Reedy, TB
# Ifeanyi Momah, ARI
# Darrell Daniels, IND
# Chris Matthews, BAL
# Fitzgerald Toussaint, PIT
# Sean Mannion, LAR
# Josh Ferguson, IND
# Mack Brown, MIN
# Danny Vitale, CLE
# Joe Webb, HOU
# Derrick Coleman, ARI
# Geoff Swaim, DAL
# Antony Auclair, TB
# JoJo Natson, NYJ
# Senorise Perry, MIA
# Ryan Hewitt, CIN
# Jehu Chesson, KC
# Michael Burton, CHI
# Chris Manhertz, CAR
# Jordan Leslie, DEN
# Cole Hikutini, SF
# MarQueis Gray, MIA
# DeAndrew White, HOU
# Isaiah McKenzie, DEN
# Darius Powe, NYG
# Jeff Janis, CLE
# Shelton Gibson, PHI
# Cody Kessler, JAX
# Allen Robinson, CHI
# AJ McCarron, BUF
# Kevin White, CHI
# Andre Williams, LAC
# Matt Cassel, DET
# Arrelious Benn, JAX
# Jeff Cumberland, LAC
# Taiwan Jones, BUF
# David Fluellen, TEN
# Harry Douglas, TEN
# Cobi Hamilton, ARI
# Eric Weems, TEN
# Matt Jones, PHI
# LeShun Daniels Jr., WSH
# Max McCaffrey, SF
# Cooper Rush, DAL
# Scott Tolzien, FA
# Charone Peake, NYJ
# Matt Hazel, CLE
# Devante Mays, GB
# Raheem Mostert, SF
# Terrell Watson, NYG
# Taylor Heinicke, CAR
# Derek Anderson, FA
# Joe Callahan, PHI
# Andre Roberts, NYJ
# John Kuhn, NO
# Kalif Raymond, NYG
# Justin Davis, LAR
# Shaun Hill, MIN
# Anquan Boldin, BUF
# Matt Schaub, ATL
# DeAngelo Williams, PIT
# Devin Hester, SEA
# Charlie Whitehurst, CLE
# Calvin Johnson, DET
# Eddie Royal, CHI
# Gary Barnidge, CLE
# Jerome Felton, BUF
# Tim Hightower, SF
# Matthew Slater, NE
# Kellen Davis, NYJ
# Josh Johnson, OAK
# Justin Forsett, DEN
# Matthew Mulligan, DET
# Marcel Reece, SEA
# Josh Freeman, IND
# Mark Sanchez, FA
# Rashad Jennings, NYG
# David Johnson, PIT
# Cedric Peerman, CIN
# Chase Coffman, IND
# John Phillips, NO
# Percy Harvin*, BUF
# Jordan Norwood, DEN
# Julian Edelman, NE
# Brandon Myers, TB
# Antone Smith, TB
# Colt McCoy, WSH
# C.J. Spiller, KC
# Ryan Mathews, PHI
# Dexter McCluster, LAC
# James Starks, GB
# Dennis Pitta*, BAL
# Jim Dray, ARI
# Clay Harbor, NO
# Marc Mariani, TEN
# Andrew Quarless, DET
# Joique Bell, DET
# Victor Cruz, CHI
# Marlon Moore*, CLE
# Bryan Walters, JAX
# Logan Paulsen, ATL
# Andrew Hawkins, CLE
# Colin Kaepernick, FA
# Rob Housler, NE
# Bruce Miller, SF
# Dwayne Harris, OAK
# Greg Salas, BUF
# Cecil Shorts III, TB
# Jordan Todman, HOU
# Jordan Cameron, MIA
# DuJuan Harris, JAX
# Matt Asiata, DET
# Jeremy Ross, ARI
# Shaun Draughn, NYG
# Andrew Luck, IND
# Robert Griffin III, BAL
# Ryan Tannehill, MIA
# Brandon Weeden, HOU
# Isaiah Pead*, MIA
# Ronnie Hillman, DAL
# Ladarius Green, PIT
# DeVier Posey, BAL
# Daryl Richardson, IND
# Greg Scruggs, NE
# Nathan Palmer, OAK
# Cory Harkey, LAR
# Joe Banyard, BUF
# Dominique Jones, MIA
# Rod Streater, BUF
# Jonathan Grimes, JAX
# Brandon Bostick, NYJ
# Alex Tanney, NYG
# Larry Donnell, BAL
# Knile Davis, PIT
# Gavin Escobar, MIA
# Christine Michael, IND
# Charles Johnson, NYJ
# Ryan Nassib, JAX
# B.J. Daniels, ATL
# Mychal Rivera, JAX
# Zac Dysert, ARI
# Chris Gragg, NYJ
# Matt Barkley, CIN
# Denard Robinson, JAX
# Mike James, DET
# Stepfan Taylor, ARI
# Corey Fuller, NO
# Spencer Ware, KC
# Marquess Wilson, PHI
# Quinton Patton, NYJ
# Ryan Griffin, TB
# Tim Wright, KC
# Kenbrell Thompkins, NYJ
# George Winn, IND
# Khiry Robinson, NYJ
# Marlon Brown, CHI
# Matt McGloin, KC
# Johnny Manziel, CLE
# Crockett Gillmore, BAL
# Josh Huff, NO
# Tre Mason, LAR
# Jace Amaro, KC
# Bishop Sankey, MIN
# Shaq Evans, DAL
# Zach Mettenberger, PIT
# Tyler Gaffney, JAX
# Kevin Norwood, NYG
# Ka'Deem Carey, CHI
# Lorenzo Taliaferro, BAL
# Devin Street, HOU
# Juwan Thompson, DEN
# Antonio Andrews, TEN
# Corey Brown, BUF
# Frankie Hammond, NYJ
# Austin Johnson, TB
# James Wright, IND
# Isaiah Burse, LAC
# Jeremy Butler, BUF
# Walter Powell, BUF
# Asante Cleveland, LAC
# Rashad Ross, ARI
# Justin Perillo, CHI
# MyCole Pruitt, HOU
# Gerald Christian, ARI
# Geremy Davis, LAC
# Kenny Bell, DEN
# Dres Anderson, IND
# Jeremy Langford, NYJ
# Keith Mumphery, HOU
# Malcolm Johnson, SF
# Dezmin Lewis, BUF
# Garrett Grayson, ATL
# Devin Smith, NYJ
# Rashad Greene Sr., JAX
# Karlos Williams, PIT
# Darren Waller, BAL
# Kenny Hilliard, WSH
# Kennard Backman, DET
# Dorial Green-Beckham, PHI
# Mario Alford, CLE
# DeAndre Smelter, IND
# John Crockett, BAL
# Terrence Magee, ATL
# Seantavius Jones, IND
# Cameron Meredith, NO
# E.J. Bibbs, WSH
# Khari Lee, BUF
# Lucky Whitehead, NYJ
# Quincy Enunwa, NYJ
# Chris Harper, NYJ
# Bradley Marquez, DET
# Donteea Dye, TB
# Trey Williams, DAL
# Christian Hackenberg, OAK
# Connor Cook, OAK
# Malcolm Mitchell, NE
# Kenneth Dixon, BAL
# Cardale Jones, LAC
# Tajae Sharpe, TEN
# Jordan Payton, CLE
# Jonathan Williams, NO
# Temarrick Hemingway, LAR
# Moritz Bohringer, CIN
# Keenan Reynolds, SEA
# Kolby Listenbee*, IND
# Cody Core, CIN
# Brandon Allen, LAR
# Jeff Driskel, CIN
# Kelvin Taylor, CLE
# Aaron Burbridge, SF
# Darius Jackson, DAL
# Rico Gathers, DAL
# Brandon Doughty, ARI
# Devin Lucien, TB
# Demarcus Ayers, CHI
# Daniel Braverman, KC
# Thomas Duarte, MIA
# Daniel Lasco, NO
# Devin Lewis Fuller, ATL
# Keith Marshall, WSH
# Kenny Lawler, SEA
# Zac Brooks, SEA
# Beau Sandland, ARI
# Trevone Boykin, SEA
# Ben Braunecker, CHI
# Cole Wick, SF
# Matt LaCosse, DEN
# Erik Swoope, IND
# Brandon Wilds, JAX
# Jhurell Pressley, ATL
# Jake Kumerow, GB
# George Atkinson III, KC
# Bryce Williams, ARI
# Marquez North, LAR
# Andy Jones, DET
# Xavier Rush, NO
# Dom Williams, PHI
# Paul McRoberts, LAR
# Wendall Williams, HOU
# Anthony Dable, ATL
# Darius Jennings, TEN
# Devon Cajuste, CLE
# Mitch Mathews, MIA
# Stephen Morris, HOU
# Devon Johnson, CAR
# Keyarris Garrett, CAR
# Jalin Marshall, NYJ
# Braedon Bowman, LAC
# Brian Parker, DEN
# Troymaine Pope, HOU
# Glenn Gronkowski, NE
# Julian Howsare, NYJ
# Kenneth Farrow, LAC
# Nelson Spruce, LAC
# Joshua Perkins, PHI
# Paul Lasike, CHI
# Scott Simonson, CAR
# Don Jackson, GB
# Paul Turner, NO
# George Farmer, SEA
# D.J. Tialavea, ATL
# Matt Lengel, HOU
# Alex Ellis, KC
# Donnel Pumphrey, PHI
# Elijah Hood, CAR
# Brad Kaaya, IND
# Chad Kelly, DEN
# Marquez Williams, CLE
# Malachi Dupre, BUF
# Rodney Adams, MIN
# Joshua Dobbs, PIT
# Jordan Leggett, NYJ
# Jake Butt, DEN
# Mason Schreck, CIN
# Alex Armah, CAR
# David Moore, SEA
# T.J. Logan, ARI
# Carlos Henderson, DEN
# Robert Davis, WSH
# Bucky Hodges, NYJ
# Sam Rogers, LAR
# Isaiah Ford, MIA
# Eric Saubert, ATL
# Joe Williams, SF
# Stacy Coley, MIN
# Khalfani Muhammad, TEN
# Jeremy McNichols, SF
# DeAngelo Yancey, GB
# Davis Webb, NYG
# Freddie Stevenson, CHI
# Jace Billingsley, DET
# Ishmael Zamora, OAK
# Austin Carr, NO
# Hakeem Valles, DET
# Rashawn Scott, MIA
# Rannell Hall, CLE
# Algernon Brown, NYJ
# Jahad Thomas, NYJ
# Damore'ea Stringfellow, SEA
# Taquan Mizzell, CHI
# Taysom Hill, NO
# Victor Bolden Jr., SF
# Sean Culkin, LAC
# Cethan Carter, CIN
# Evan Baylis, CAR
# Shane Smith, NYG
# Krishawn Hogan, IND
# Henry Krieger-Coble, LAR
# Ed Eagan, NYG
# Carlton Agudosi, ARI
# Isaac Whitney, OAK
# Austin Davis, SEA
# Darren McFadden, DAL
# Chase Daniel, CHI
# Chad Henne, KC
# John Ross, CIN
# Jake Rudock, DET
# Kellen Clemens, LAC
# Tyler Bray, CHI
# Teddy Bridgewater, NYJ
# Baker Mayfield, CLE
# Sam Darnold, NYJ
# Saquon Barkley, NYG
# Josh Allen, BUF
# Josh Rosen, ARI
# D.J. Moore, CAR
# Hayden Hurst, BAL
# Calvin Ridley, ATL
# Rashaad Penny, SEA
# Sony Michel, NE
# Lamar Jackson, BAL
# Nick Chubb, CLE
# Ronald Jones II, TB
# Courtland Sutton, DEN
# Mike Gesicki, MIA
# Kerryon Johnson, DET
# Dante Pettis, SF
# Christian Kirk, ARI
# Dallas Goedert, PHI
# Anthony Miller, CHI
# Derrius Guice, WSH
# James Washington, PIT
# D.J. Chark, JAX
# Royce Freeman, DEN
# Mason Rudolph, PIT
# Michael Gallup, DAL
# Mark Andrews, BAL
# Tre'Quan Smith, NO
# Jordan Akins, HOU
# Ian Thomas, CAR
# Keke Coutee, HOU
# Nyheim Hines, IND
# Antonio Callaway, CLE
# Chris Herndon IV, NYJ
# Kyle Lauletta, NYG
# Mark Walton, CIN
# DaeSean Hamilton, DEN
# Will Dissly, SEA
# Durham Smythe, MIA
# Ito Smith, ATL
# Kalen Ballage, MIA
# Jaleel Scott, BAL
# J'Mon Moore, GB
# Chase Edmonds, ARI
# Dalton Schultz, DAL
# Justin Watson, TB
# Troy Fumagalli, DEN
# Tyler Conklin, MIN
# Daurice Fountain, IND
# Jordan Lasley, BAL
# Jaylen Samuels, PIT
# Jordan Wilkins, IND
# Mike White, DAL
# Marquez Valdes-Scantling, GB
# Damion Ratley, CLE
# John Kelly, LAR
# Deon Cain, IND
# Ray-Ray McCloud, BUF
# Dylan Cantrell, LAC
# Russell Gage, ATL
# Luke Falk, TEN
# Boston Scott, NO
# Tanner Lee, JAX
# Trenton Cannon, NYJ
# Equanimeous St. Brown, GB
# Cedrick Wilson, DAL
# Braxton Berrios, NE
# Jordan Thomas, HOU
# Danny Etling, NE
# Alex McGough, SEA
# Javon Wims, CHI
# David Williams, DEN
# Marcell Ateman, OAK
# Bo Scarbrough, DAL
# Nick Bawden, DET
# Richie James, SF
# Logan Woodside, CIN
# Ryan Izzo, NE
# Justin Jackson, LAC
# Auden Tate, CIN
# Austin Proehl, BUF
# Trey Quinn, WSH
# Josh Adams, PHI
# Akrum Wadley, TEN
# Blake Jarwin, DAL
# Byron Pringle, KC
# Allen Lazard, JAX

# %% [markdown]
# 6.Notice that the player names contain the name, team, and position. We will want to break this up. First, create a list called playernames that just contains the player names and teams (we need the team, too, because there are common names like David Johnson that play on two different teams).

# %%
playernames = []
for player in df['player']:
    print(player)
    line = player.split(',')
    name = line[0]
    team = line[1].split()[0].upper()
    playername = name + ', ' + team
    playernames.append(playername)
# Out:
# Todd Gurley II, LAR RB
# Russell Wilson, Sea QB
# Le'Veon Bell, Pit RB
# Alvin Kamara, NO RB
# Antonio Brown, Pit WR
# DeAndre Hopkins, Hou WR Q
# Cam Newton, Car QB Q
# Tom Brady, NE QB
# Kareem Hunt, KC RB Q
# Alex Smith, Wsh QB
# Melvin Gordon, LAC RB
# Keenan Allen, LAC WR
# Carson Wentz, Phi QB Q
# Mark Ingram, NO RB SSPD
# Kirk Cousins, Min QB
# Matthew Stafford, Det QB
# Philip Rivers, LAC QB
# LeSean McCoy, Buf RB Q
# Drew Brees, NO QB
# Larry Fitzgerald, Ari WR
# Ben Roethlisberger, Pit QB
# Dak Prescott, Dal QB
# Jarvis Landry, Cle WR
# Michael Thomas, NO WR
# Jared Goff, LAR QB
# Julio Jones, Atl WR
# Blake Bortles, Jax QB
# Tyreek Hill, KC WR
# Adam Thielen, Min WR
# Case Keenum, Den QB
# Carlos Hyde, Cle RB
# Travis Kelce, KC TE
# Leonard Fournette, Jax RB
# Christian McCaffrey, Car RB
# Matt Ryan, Atl QB
# Rob Gronkowski, NE TE
# A.J. Green, Cin WR
# Marvin Jones Jr., Det WR
# Golden Tate, Det WR
# Doug Baldwin, Sea WR
# Tyrod Taylor, Cle QB
# Davante Adams, GB WR Q
# Brandin Cooks, LAR WR Q
# Duke Johnson Jr., Cle RB
# Andy Dalton, Cin QB
# Marcus Mariota, Ten QB
# Derek Carr, Oak QB
# Jacoby Brissett, Ind QB
# Demaryius Thomas, Den WR
# Josh McCown, NYJ QB Q
# Ezekiel Elliott, Dal RB
# Mike Evans, TB WR
# Dion Lewis, Ten RB
# Zach Ertz, Phi TE
# Jameis Winston, TB QB
# Devonta Freeman, Atl RB Q
# Robby Anderson, NYJ WR
# Jordan Howard, Chi RB
# Stefon Diggs, Min WR
# JuJu Smith-Schuster, Pit WR
# Alshon Jeffery, Phi WR Q
# Devin Funchess, Car WR
# Lamar Miller, Hou RB
# Nelson Agholor, Phi WR
# Eli Manning, NYG QB
# Dez Bryant, FA WR
# Joe Flacco, Bal QB
# Jerick McKinnon, SF RB
# Cooper Kupp, LAR WR
# Jermaine Kearse, NYJ WR
# DeShone Kizer, GB QB
# T.Y. Hilton, Ind WR
# C.J. Anderson, Car RB
# Kenny Stills, Mia WR
# Delanie Walker, Ten TE
# Mohamed Sanu, Atl WR Q
# Frank Gore, Mia RB
# Evan Engram, NYG TE
# Michael Crabtree, Bal WR
# DeMarco Murray, FA RB
# Jimmy Graham, GB TE
# Alex Collins, Bal RB
# Jack Doyle, Ind TE
# Deshaun Watson, Hou QB Q
# Marquise Goodwin, SF WR
# Tevin Coleman, Atl RB
# Javorius Allen, Bal RB
# Marshawn Lynch, Oak RB
# Robert Woods, LAR WR
# Jamison Crowder, Wsh WR
# Ted Ginn Jr., NO WR
# Randall Cobb, GB WR
# Amari Cooper, Oak WR Q
# Kyle Rudolph, Min TE Q
# Jay Cutler, FA QB
# Latavius Murray, Min RB
# Rishard Matthews, Ten WR Q
# Theo Riddick, Det RB
# Giovani Bernard, Cin RB
# Chris Thompson, Wsh RB Q
# Mike Wallace, Phi WR
# Paul Richardson, Wsh WR
# Tarik Cohen, Chi RB
# Marqise Lee, Jax WR
# Jason Witten, Dal TE
# Sammy Watkins, KC WR
# Bilal Powell, NYJ RB
# Sterling Shepard, NYG WR
# Isaiah Crowell, NYJ RB
# Cameron Brate, TB TE
# Jamaal Williams, GB RB
# Kenyan Drake, Mia RB
# Joe Mixon, Cin RB
# Danny Amendola, Mia WR
# DeSean Jackson, TB WR
# Tyrell Williams, LAC WR
# Orleans Darkwa, NYG RB Q
# Benjamin Watson, NO TE
# Jordy Nelson, Oak WR
# Kelvin Benjamin, Buf WR
# Jay Ajayi, Phi RB
# Derrick Henry, Ten RB
# Mitchell Trubisky, Chi QB
# James White, NE RB
# Jared Cook, Oak TE
# Keelan Cole, Jax WR
# Martavis Bryant, Oak WR
# Eric Ebron, Ind TE
# Travis Benjamin, LAC WR
# DeVante Parker, Mia WR
# Rex Burkhead, NE RB
# Aaron Rodgers, GB QB
# Adam Humphries, TB WR
# Hunter Henry*, LAC TE O
# Kendall Wright, Min WR
# Ryan Grant, Ind WR
# Trevor Siemian, Min QB Q
# Brandon LaFell, Cin WR
# Brett Hundley, GB QB
# Ameer Abdullah, Det RB
# Tyler Kroft, Cin TE
# Tyler Lockett, Sea WR
# Vernon Davis, Wsh TE
# Matt Forte, NYJ RB
# Josh Doctson, Wsh WR
# Austin Hooper, Atl TE
# Jonathan Stewart, NYG RB
# Charles Clay, Buf TE
# Eric Decker, FA WR
# Albert Wilson, Mia WR
# Emmanuel Sanders, Den WR
# Will Fuller V, Hou WR
# Terrance Williams, Dal WR Q
# Chris Hogan, NE WR
# Samaje Perine, Wsh RB
# LeGarrette Blount, Det RB
# Austin Ekeler, LAC RB
# George Kittle, SF TE
# Deonte Thompson, Dal WR
# Wayne Gallman, NYG RB
# Matt Breida, SF RB
# Marlon Mack, Ind RB Q
# Jaron Brown, Sea WR
# Carson Palmer, Ari QB
# Jeremy Maclin, FA WR
# Austin Seferian-Jenkins, Jax TE
# O.J. Howard, TB TE
# Allen Hurns, Dal WR
# Jesse James, Pit TE
# Julius Thomas, Mia TE Q
# J.D. McKissic, Sea RB
# Trent Taylor, SF WR Q
# David Njoku, Cle TE
# Kenny Golladay, Det WR
# J.J. Nelson, Ari WR
# Chris Godwin, TB WR
# Rod Smith, Dal RB
# Corey Clement, Phi RB
# Ty Montgomery, GB RB
# Cole Beasley, Dal WR
# Devontae Booker, Den RB
# Torrey Smith, Car WR
# Seth Roberts, Oak WR
# Pierre Garcon, SF WR Q
# Roger Lewis, NYG WR Q
# C.J. Beathard, SF QB
# Jimmy Garoppolo, SF QB
# Marcedes Lewis, GB TE
# T.J. Yeldon, Jax RB
# Andre Ellington, Hou RB
# Jalen Richard, Oak RB
# Cordarrelle Patterson, NE WR
# Peyton Barber, TB RB
# DeAndre Washington, Oak RB
# Chris Ivory, Buf RB
# TJ Jones, Det WR Q
# Shane Vereen, FA RB
# Bennie Fowler III, Chi WR
# Taylor Gabriel, Chi WR
# Aaron Jones, GB RB
# Trey Burton, Chi TE
# Ed Dickson, Sea TE
# Antonio Gates, LAC TE
# Adrian Peterson, FA RB
# Garrett Celek, SF TE
# Jermaine Gresham, Ari TE Q
# Donte Moncrief, Jax WR
# Seth DeValve, Cle TE
# Elijah McGuire, NYJ RB
# Doug Martin, Oak RB
# Bruce Ellington, Hou WR Q
# Odell Beckham Jr., NYG WR Q
# Ryan Fitzpatrick, TB QB
# Charles Sims, TB RB
# Brandon Coleman, NO WR
# Charcandrick West, KC RB
# Alfred Morris, Dal RB
# Zay Jones, Buf WR Q
# John Brown, Bal WR
# Kyle Juszczyk, SF RB
# Corey Davis, Ten WR
# Mike Gillislee, NE RB
# Rashard Higgins, Cle WR
# Joshua Bellamy, Chi WR
# Brock Osweiler, Mia QB
# Kerwynn Williams, KC RB
# Jamaal Charles, FA RB
# Dede Westbrook, Jax WR
# Chris Moore, Bal WR
# Corey Coleman, Cle WR
# Dalvin Cook, Min RB Q
# Dontrelle Inman, Chi WR
# Stephen Anderson, Hou TE
# Brice Butler, Ari WR
# Nick O'Leary, Buf TE
# Brian Hoyer, NE QB
# Coby Fleener, NO TE Q
# Ricardo Louis, Cle WR
# Cody Latimer, NYG WR
# Blaine Gabbert, Ten QB
# Tyler Higbee, LAR TE
# Tavarres King, Min WR
# Jordan Reed, Wsh TE Q
# Justin Hardy, Atl WR Q
# Damien Williams, KC RB Q
# Rhett Ellison, NYG TE
# Martellus Bennett, NE TE
# Danny Woodhead, Bal RB
# Chester Rogers, Ind WR
# Kenny Britt, NE WR
# Josh Gordon, Cle WR
# Jordan Matthews, NE WR Q
# Aldrick Robinson, SF WR
# D'Onta Foreman, Hou RB Q
# Benny Cunningham, Chi RB
# Tyler Boyd, Cin WR
# Zach Miller*, Chi TE O
# A.J. Derby, Mia TE
# Luke Willson, Det TE
# Darren Fells, Cle TE
# Michael Campanaro, Ten WR
# Mike Davis, Sea RB
# Gerald Everett, LAR TE
# Malcolm Brown, LAR RB
# Tom Savage, NO QB
# Mike Tolbert, Buf RB
# Drew Stanton, Cle QB Q
# Nick Boyle, Bal TE
# Ricky Seals-Jones, Ari TE
# Terrelle Pryor Sr., NYJ WR Q
# Jarius Wright, Car WR
# Taywan Taylor, Ten WR
# Jacquizz Rodgers, TB RB
# Wendell Smallwood, Phi RB
# Demetrius Harris, KC TE SSPD
# Geronimo Allison, GB WR
# Jeremy Kerley, Buf WR
# Jonnu Smith, Ten TE
# Russell Shepard, NYG WR
# Johnny Holton, Oak WR
# Alfred Blue, Hou RB
# Mack Hollins, Phi WR
# Jakeem Grant, Mia WR
# Lance Kendricks, GB TE
# Rob Kelley, Wsh RB Q
# Andre Holmes, Buf WR Q
# Tavon Austin, Dal RB
# Adam Shaheen, Chi TE
# Demarcus Robinson, KC WR
# Greg Olsen, Car TE
# Corey Grant, Jax RB
# Kendrick Bourne, SF WR
# Matt Moore, FA QB
# Braxton Miller, Hou WR
# De'Anthony Thomas, KC WR Q
# Kapri Bibbs, Wsh RB Q
# Laquon Treadwell, Min WR Q
# Damiere Byrd, Car WR
# Chris Carson, Sea RB
# Virgil Green, LAC TE
# Dion Sims, Chi TE
# Vance McDonald, Pit TE
# Travaris Cadet, Buf RB Q
# Eli Rogers, Pit WR Q
# Ryan Griffin, Hou TE
# Levine Toilolo, Det TE
# Alex Erickson, Cin WR
# Jeff Heuerman, Den TE
# James O'Shaughnessy, Jax TE
# T.J. Yates, FA QB
# Richard Rodgers, Phi TE
# Nick Foles, Phi QB
# Kevin Hogan, Wsh QB
# Mike Glennon, Ari QB
# Brandon Marshall, Sea WR
# Curtis Samuel, Car WR Q
# D.J. Foster, Ari RB
# Elijhaa Penny, Ari RB
# Phillip Dorsett, NE WR
# Thomas Rawls, NYJ RB
# Brent Celek, Phi TE
# Tion Green, Det RB
# Nick Vannett, Sea TE
# Troy Niklas, NE TE
# Josh Hill, NO TE Q
# Tommy Bohanon, Jax RB
# Anthony Fasano, Mia TE
# Eddie Lacy, FA RB
# Chris Conley, KC WR Q
# Kamar Aiken, Ind WR
# Maxx Williams, Bal TE
# Terrance West, Bal RB
# Josh Reynolds, LAR WR
# Jordan Taylor, Den WR Q
# Tommylee Lewis, NO WR
# Sam Bradford, Ari QB
# C.J. Fiedorowicz, Hou TE
# Louis Murphy, SF WR
# Eric Tomlinson, NYJ TE
# Robert Turbin, Ind RB
# Daniel Brown, Chi TE
# David Morgan, Min TE
# Bryce Petty, Mia QB
# C.J. Uzomah, Cin TE
# Brandon Williams, Ind TE Q
# Dwayne Allen, NE TE
# Pharoh Cooper, LAR WR
# Niles Paul, Jax TE
# Tre McBride III, NYJ WR Q
# Kenjon Barner, Car RB
# Paul Perkins*, NYG RB O
# Jaydon Mickens, Jax WR
# Kaelin Clay, Buf WR
# C.J. Ham, Min RB
# Brenton Bersin, Car WR
# Chris Johnson, Ari RB
# Anthony Sherman, KC RB
# Mike Williams, LAC WR Q
# Brandon Tate, Buf WR
# Logan Thomas, Buf TE Q
# Jamize Olawale, Dal RB
# David Fales, Mia QB
# James Hanna, Dal TE
# Josh Malone, Cin WR
# Darren Sproles, Phi RB Q
# Chad Hansen, NYJ WR
# Travis Rudolph, NYG WR
# Michael Floyd, Min WR
# Breshad Perriman, Bal WR
# Fozzy Whittaker*, Car RB IR
# Kasen Williams, Ind WR
# Jeremy Hill, NE RB
# Jerell Adams, NYG TE
# Michael Hoomanawanui, NO TE
# Clive Walford, NYJ TE
# C.J. Prosise, Sea RB Q
# ArDarius Stewart, NYJ WR
# Branden Oliver, LAC RB
# Stevan Ridley, Pit RB
# Cameron Artis-Payne, Car RB
# Maurice Harris, Wsh WR
# Darrius Heyward-Bey, Pit WR
# Lee Smith, Oak TE
# Terron Ward, Atl RB
# Willie Snead, Bal WR
# Derek Carrier, Oak TE
# Amara Darboh, Sea WR
# Paxton Lynch, Den QB
# Andy Janovich, Den RB
# Freddie Martino, TB WR
# Ross Travis, Ind TE
# Ryan Switzer, Oak WR
# Roosevelt Nix, Pit RB
# James Conner, Pit RB
# Michael Thomas, LAR WR
# Neal Sterling, NYJ TE
# Xavier Grimble, Pit TE
# EJ Manuel, Oak QB
# Marvin Hall, Atl WR
# Phillip Supernaw, Ten TE
# Leonte Carroo, Mia WR Q
# Brian Quick, Wsh WR
# Chris Thompson, Hou WR
# Trevor Davis, GB WR Q
# Aaron Ripkowski, GB RB
# Luke Stocker, Ten TE
# Bobby Rainey Jr., Bal RB
# David Johnson, Ari RB
# Sammie Coates, Hou WR
# Tyler Ervin, Hou WR Q
# De'Angelo Henderson, Den RB
# Jaelen Strong, Jax WR Q
# Byron Marshall, Wsh RB Q
# Justin Hunter, Pit WR
# Tanner McEvoy, Sea WR
# Lance Dunbar, LAR RB
# Brittan Golden, Ari WR Q
# Zach Line, NO RB
# Bryce Treggs, Phi WR
# Ben Koyack, Jax TE
# Alan Cross, TB TE Q
# Trey Edmunds, NO RB
# Austin Traylor, Den TE
# Nathan Peterman, Buf QB
# Patrick Mahomes, KC QB
# Ryan Mallett, FA QB
# James Develin, NE RB
# Geno Smith, LAC QB
# Patrick DiMarco, Buf RB
# Akeem Hunt*, KC RB IR
# Chad Williams, Ari WR
# Jeremy Sprinkle, Wsh TE
# Brian Hill, Cin RB
# Jacob Hollister, NE TE
# Sean McGrath, LAC TE
# Tyler Eifert, Cin TE Q
# Michael Roberts, Det TE
# Zach Zenner, Det RB
# Landry Jones, Pit QB
# Tre Madden, Sea RB Q
# Brandon Bolden, NE RB
# Matthew Dayes, Cle RB
# Markus Wheaton, Phi WR
# Michael Clark, GB WR
# Derek Watt, LAC RB
# Will Tye, NE TE
# Dwayne Washington, Det RB
# Keith Smith, Oak RB
# Nate Sudfeld, Phi QB
# Marcus Johnson, Sea WR
# Jared Abbrederis, Det WR
# Orson Charles, KC TE
# Noah Brown, Dal WR
# Jay Prosch, Hou RB
# Blake Bell, Min TE Q
# Quan Bray, Buf WR
# Marcus Murphy, Buf RB
# Randall Telfer, Cle TE Q
# Tanner Gentry, Chi WR
# Jalston Fowler, Sea RB
# Griff Whalen, Oak WR
# Vince Mayle, Bal TE
# Nick Williams, Ten WR
# Bernard Reedy, TB WR
# Ifeanyi Momah, Ari TE Q
# Darrell Daniels, Ind TE
# Chris Matthews, Bal WR
# Fitzgerald Toussaint, Pit RB
# Sean Mannion, LAR QB
# Josh Ferguson, Ind RB
# Mack Brown, Min RB
# Danny Vitale, Cle RB
# Joe Webb, Hou QB
# Derrick Coleman, Ari RB
# Geoff Swaim, Dal TE Q
# Antony Auclair, TB TE
# JoJo Natson, NYJ WR
# Senorise Perry, Mia RB
# Ryan Hewitt, Cin RB
# Jehu Chesson, KC WR
# Michael Burton, Chi RB
# Chris Manhertz, Car TE
# Jordan Leslie, Den WR
# Cole Hikutini, SF TE Q
# MarQueis Gray, Mia TE
# DeAndrew White, Hou WR
# Isaiah McKenzie, Den WR
# Darius Powe, NYG WR Q
# Jeff Janis, Cle WR
# Shelton Gibson, Phi WR
# Cody Kessler, Jax QB
# Allen Robinson, Chi WR Q
# AJ McCarron, Buf QB
# Kevin White, Chi WR
# Andre Williams, LAC RB Q
# Matt Cassel, Det QB
# Arrelious Benn, Jax WR Q
# Jeff Cumberland, LAC TE
# Taiwan Jones, Buf RB Q
# David Fluellen, Ten RB
# Harry Douglas, Ten WR
# Cobi Hamilton, Ari WR
# Eric Weems, Ten WR
# Matt Jones, Phi RB
# LeShun Daniels Jr., Wsh RB
# Max McCaffrey, SF WR
# Cooper Rush, Dal QB
# Scott Tolzien, FA QB
# Charone Peake, NYJ WR Q
# Matt Hazel, Cle WR
# Devante Mays, GB RB
# Raheem Mostert, SF RB Q
# Terrell Watson, NYG RB
# Taylor Heinicke, Car QB
# Derek Anderson, FA QB
# Joe Callahan, Phi QB
# Andre Roberts, NYJ WR
# John Kuhn, NO RB Q
# Kalif Raymond, NYG WR
# Justin Davis, LAR RB
# Shaun Hill, Min QB
# Anquan Boldin, Buf WR
# Matt Schaub, Atl QB
# DeAngelo Williams, Pit RB
# Devin Hester, Sea WR
# Charlie Whitehurst, Cle QB Q
# Calvin Johnson, Det WR
# Eddie Royal, Chi WR
# Gary Barnidge, Cle TE
# Jerome Felton, Buf RB
# Tim Hightower, SF RB
# Matthew Slater, NE WR
# Kellen Davis, NYJ TE Q
# Josh Johnson, Oak QB
# Justin Forsett, Den RB
# Matthew Mulligan, Det TE
# Marcel Reece, Sea RB
# Josh Freeman, Ind QB
# Mark Sanchez, FA QB SSPD
# Rashad Jennings, NYG RB
# David Johnson, Pit TE
# Cedric Peerman, Cin RB Q
# Chase Coffman, Ind TE
# John Phillips, NO TE
# Percy Harvin*, Buf WR O
# Jordan Norwood, Den WR
# Julian Edelman, NE WR Q
# Brandon Myers, TB TE
# Antone Smith, TB RB
# Colt McCoy, Wsh QB
# C.J. Spiller, KC RB
# Ryan Mathews, Phi RB
# Dexter McCluster, LAC RB
# James Starks, GB RB
# Dennis Pitta*, Bal TE O
# Jim Dray, Ari TE
# Clay Harbor, NO TE
# Marc Mariani, Ten WR
# Andrew Quarless, Det TE
# Joique Bell, Det RB
# Victor Cruz, Chi WR
# Marlon Moore*, Cle WR O
# Bryan Walters, Jax WR Q
# Logan Paulsen, Atl TE
# Andrew Hawkins, Cle WR
# Colin Kaepernick, FA QB
# Rob Housler, NE TE Q
# Bruce Miller, SF TE
# Dwayne Harris, Oak WR
# Greg Salas, Buf WR Q
# Cecil Shorts III, TB WR
# Jordan Todman, Hou RB Q
# Jordan Cameron, Mia TE Q
# DuJuan Harris, Jax RB
# Matt Asiata, Det RB
# Jeremy Ross, Ari WR
# Shaun Draughn, NYG RB
# Andrew Luck, Ind QB Q
# Robert Griffin III, Bal QB
# Ryan Tannehill, Mia QB Q
# Brandon Weeden, Hou QB
# Isaiah Pead*, Mia RB O
# Ronnie Hillman, Dal RB
# Ladarius Green, Pit TE Q
# DeVier Posey, Bal WR
# Daryl Richardson, Ind RB
# Greg Scruggs, NE TE Q
# Nathan Palmer, Oak WR
# Cory Harkey, LAR RB
# Joe Banyard, Buf RB
# Dominique Jones, Mia TE
# Rod Streater, Buf WR
# Jonathan Grimes, Jax RB
# Brandon Bostick, NYJ TE
# Alex Tanney, NYG QB
# Larry Donnell, Bal TE
# Knile Davis, Pit RB
# Gavin Escobar, Mia TE
# Christine Michael, Ind RB
# Charles Johnson, NYJ WR Q
# Ryan Nassib, Jax QB
# B.J. Daniels, Atl WR
# Mychal Rivera, Jax TE Q
# Zac Dysert, Ari QB Q
# Chris Gragg, NYJ TE Q
# Matt Barkley, Cin QB
# Denard Robinson, Jax RB
# Mike James, Det RB Q
# Stepfan Taylor, Ari RB
# Corey Fuller, NO WR
# Spencer Ware, KC RB Q
# Marquess Wilson, Phi WR
# Quinton Patton, NYJ WR Q
# Ryan Griffin, TB QB
# Tim Wright, KC TE
# Kenbrell Thompkins, NYJ WR
# George Winn, Ind RB Q
# Khiry Robinson, NYJ RB
# Marlon Brown, Chi WR
# Matt McGloin, KC QB
# Johnny Manziel, Cle QB
# Crockett Gillmore, Bal TE Q
# Josh Huff, NO WR SSPD
# Tre Mason, LAR RB
# Jace Amaro, KC TE
# Bishop Sankey, Min RB Q
# Shaq Evans, Dal WR
# Zach Mettenberger, Pit QB
# Tyler Gaffney, Jax RB
# Kevin Norwood, NYG WR
# Ka'Deem Carey, Chi RB Q
# Lorenzo Taliaferro, Bal RB
# Devin Street, Hou WR Q
# Juwan Thompson, Den RB
# Antonio Andrews, Ten RB
# Corey Brown, Buf WR
# Frankie Hammond, NYJ WR
# Austin Johnson, TB RB
# James Wright, Ind WR
# Isaiah Burse, LAC WR
# Jeremy Butler, Buf WR Q
# Walter Powell, Buf WR
# Asante Cleveland, LAC TE
# Rashad Ross, Ari WR
# Justin Perillo, Chi TE
# MyCole Pruitt, Hou TE Q
# Gerald Christian, Ari TE
# Geremy Davis, LAC WR
# Kenny Bell, Den WR
# Dres Anderson, Ind WR
# Jeremy Langford, NYJ RB
# Keith Mumphery, Hou WR
# Malcolm Johnson, SF RB
# Dezmin Lewis, Buf WR
# Garrett Grayson, Atl QB
# Devin Smith, NYJ WR Q
# Rashad Greene Sr., Jax WR Q
# Karlos Williams, Pit RB SSPD
# Darren Waller, Bal TE SSPD
# Kenny Hilliard, Wsh RB
# Kennard Backman, Det TE
# Dorial Green-Beckham, Phi WR
# Mario Alford, Cle WR
# DeAndre Smelter, Ind WR
# John Crockett, Bal RB
# Terrence Magee, Atl RB
# Seantavius Jones, Ind WR
# Cameron Meredith, NO WR Q
# E.J. Bibbs, Wsh TE
# Khari Lee, Buf TE
# Lucky Whitehead, NYJ WR
# Quincy Enunwa, NYJ WR Q
# Chris Harper, NYJ WR
# Bradley Marquez, Det WR
# Donteea Dye, TB WR
# Trey Williams, Dal RB
# Christian Hackenberg, Oak QB
# Connor Cook, Oak QB
# Malcolm Mitchell, NE WR Q
# Kenneth Dixon, Bal RB
# Cardale Jones, LAC QB
# Tajae Sharpe, Ten WR
# Jordan Payton, Cle WR
# Jonathan Williams, NO RB
# Temarrick Hemingway, LAR TE Q
# Moritz Bohringer, Cin WR
# Keenan Reynolds, Sea WR
# Kolby Listenbee*, Ind WR IR
# Cody Core, Cin WR
# Brandon Allen, LAR QB
# Jeff Driskel, Cin QB Q
# Kelvin Taylor, Cle RB
# Aaron Burbridge, SF WR Q
# Darius Jackson, Dal RB Q
# Rico Gathers, Dal TE
# Brandon Doughty, Ari QB
# Devin Lucien, TB WR
# Demarcus Ayers, Chi WR
# Daniel Braverman, KC WR
# Thomas Duarte, Mia TE
# Daniel Lasco, NO RB Q
# Devin Lewis Fuller, Atl WR
# Keith Marshall, Wsh RB Q
# Kenny Lawler, Sea WR
# Zac Brooks, Sea RB
# Beau Sandland, Ari TE
# Trevone Boykin, Sea QB
# Ben Braunecker, Chi TE
# Cole Wick, SF TE
# Matt LaCosse, Den TE
# Erik Swoope, Ind TE Q
# Brandon Wilds, Jax RB
# Jhurell Pressley, Atl RB
# Jake Kumerow, GB WR
# George Atkinson III, KC RB
# Bryce Williams, Ari TE
# Marquez North, LAR WR
# Andy Jones, Det WR
# Xavier Rush, NO WR
# Dom Williams, Phi WR Q
# Paul McRoberts, LAR WR
# Wendall Williams, Hou WR
# Anthony Dable, Atl WR
# Darius Jennings, Ten WR
# Devon Cajuste, Cle TE
# Mitch Mathews, Mia WR
# Stephen Morris, Hou QB
# Devon Johnson, Car RB
# Keyarris Garrett, Car WR Q
# Jalin Marshall, NYJ WR
# Braedon Bowman, LAC TE
# Brian Parker, Den TE
# Troymaine Pope, Hou RB
# Glenn Gronkowski, NE RB
# Julian Howsare, NYJ RB
# Kenneth Farrow, LAC RB
# Nelson Spruce, LAC WR
# Joshua Perkins, Phi TE
# Paul Lasike, Chi RB
# Scott Simonson, Car TE Q
# Don Jackson, GB RB
# Paul Turner, NO WR
# George Farmer, Sea RB
# D.J. Tialavea, Atl TE
# Matt Lengel, Hou TE
# Alex Ellis, KC TE
# Donnel Pumphrey, Phi RB
# Elijah Hood, Car RB
# Brad Kaaya, Ind QB
# Chad Kelly, Den QB Q
# Marquez Williams, Cle RB
# Malachi Dupre, Buf WR
# Rodney Adams, Min WR
# Joshua Dobbs, Pit QB
# Jordan Leggett, NYJ TE
# Jake Butt, Den TE
# Mason Schreck, Cin TE Q
# Alex Armah, Car RB
# David Moore, Sea WR
# T.J. Logan, Ari RB
# Carlos Henderson, Den WR Q
# Robert Davis, Wsh WR Q
# Bucky Hodges, NYJ TE
# Sam Rogers, LAR RB
# Isaiah Ford, Mia WR Q
# Eric Saubert, Atl TE
# Joe Williams, SF RB
# Stacy Coley, Min WR
# Khalfani Muhammad, Ten RB
# Jeremy McNichols, SF RB
# DeAngelo Yancey, GB WR
# Davis Webb, NYG QB
# Freddie Stevenson, Chi RB
# Jace Billingsley, Det WR
# Ishmael Zamora, Oak WR
# Austin Carr, NO WR
# Hakeem Valles, Det TE
# Rashawn Scott, Mia WR
# Rannell Hall, Cle WR
# Algernon Brown, NYJ RB
# Jahad Thomas, NYJ RB
# Damore'ea Stringfellow, Sea WR
# Taquan Mizzell, Chi RB
# Taysom Hill, NO QB
# Victor Bolden Jr., SF WR
# Sean Culkin, LAC TE
# Cethan Carter, Cin RB
# Evan Baylis, Car TE
# Shane Smith, NYG RB
# Krishawn Hogan, Ind WR Q
# Henry Krieger-Coble, LAR TE
# Ed Eagan, NYG WR
# Carlton Agudosi, Ari WR
# Isaac Whitney, Oak WR
# Austin Davis, Sea QB
# Darren McFadden, Dal RB
# Chase Daniel, Chi QB
# Chad Henne, KC QB
# John Ross, Cin WR
# Jake Rudock, Det QB
# Kellen Clemens, LAC QB
# Tyler Bray, Chi QB
# Teddy Bridgewater, NYJ QB Q
# Baker Mayfield, Cle QB
# Sam Darnold, NYJ QB
# Saquon Barkley, NYG RB
# Josh Allen, Buf QB
# Josh Rosen, Ari QB
# D.J. Moore, Car WR
# Hayden Hurst, Bal TE
# Calvin Ridley, Atl WR
# Rashaad Penny, Sea RB
# Sony Michel, NE RB
# Lamar Jackson, Bal QB
# Nick Chubb, Cle RB
# Ronald Jones II, TB RB
# Courtland Sutton, Den WR
# Mike Gesicki, Mia TE
# Kerryon Johnson, Det RB
# Dante Pettis, SF WR
# Christian Kirk, Ari WR
# Dallas Goedert, Phi TE
# Anthony Miller, Chi WR
# Derrius Guice, Wsh RB
# James Washington, Pit WR
# D.J. Chark, Jax WR
# Royce Freeman, Den RB
# Mason Rudolph, Pit QB
# Michael Gallup, Dal WR
# Mark Andrews, Bal TE
# Tre'Quan Smith, NO WR
# Jordan Akins, Hou TE
# Ian Thomas, Car TE
# Keke Coutee, Hou WR
# Nyheim Hines, Ind RB
# Antonio Callaway, Cle WR Q
# Chris Herndon IV, NYJ TE
# Kyle Lauletta, NYG QB
# Mark Walton, Cin RB
# DaeSean Hamilton, Den WR
# Will Dissly, Sea TE
# Durham Smythe, Mia TE
# Ito Smith, Atl RB
# Kalen Ballage, Mia RB
# Jaleel Scott, Bal WR
# J'Mon Moore, GB WR
# Chase Edmonds, Ari RB
# Dalton Schultz, Dal TE
# Justin Watson, TB WR
# Troy Fumagalli, Den TE Q
# Tyler Conklin, Min TE
# Daurice Fountain, Ind WR
# Jordan Lasley, Bal WR
# Jaylen Samuels, Pit RB
# Jordan Wilkins, Ind RB
# Mike White, Dal QB
# Marquez Valdes-Scantling, GB WR
# Damion Ratley, Cle WR
# John Kelly, LAR RB
# Deon Cain, Ind WR
# Ray-Ray McCloud, Buf WR
# Dylan Cantrell, LAC WR
# Russell Gage, Atl WR
# Luke Falk, Ten QB
# Boston Scott, NO RB
# Tanner Lee, Jax QB
# Trenton Cannon, NYJ RB
# Equanimeous St. Brown, GB WR
# Cedrick Wilson, Dal WR
# Braxton Berrios, NE WR
# Jordan Thomas, Hou TE
# Danny Etling, NE QB
# Alex McGough, Sea QB
# Javon Wims, Chi WR
# David Williams, Den RB
# Marcell Ateman, Oak WR
# Bo Scarbrough, Dal RB
# Nick Bawden, Det RB
# Richie James, SF WR
# Logan Woodside, Cin QB
# Ryan Izzo, NE TE
# Justin Jackson, LAC RB
# Auden Tate, Cin WR
# Austin Proehl, Buf WR
# Trey Quinn, Wsh WR
# Josh Adams, Phi RB Q
# Akrum Wadley, Ten RB
# Blake Jarwin, Dal TE
# Byron Pringle, KC WR
# Allen Lazard, Jax WR

# %% [markdown]
# 7.We'll create a list called positions that contains just the player positions. We'll do this by splitting the phrase by spaces and saving the very last item in each phrase. In a few cases, if the name ends in something other than position (like 'Q' for questionable of 'SSPD' for suspended), we'll take the second to last item:

# %%
positions = []
for player in df['player'].values:
    position = player.split()[-1]
    if position not in ['QB', 'RB', 'WR', 'TE']:
        position = player.split()[-2]
    positions.append(position)

# %% [markdown]
# 8.Create a new data frame called "df1" where the player name called "player" is in the first column, the player position is in the second column, and the 2017 points is in the third column.

# %%
df1 = pd.DataFrame(data = {'player': playernames, 
                             'positions': positions, 
                            '2017 points': df['2017 points']})
print(df1.shape)
df1.head()
# Out:
# (890, 3)
#                 player positions 2017 points
# 0  Todd Gurley II, LAR        RB       383.3
# 1  Russell Wilson, SEA        QB       347.9
# 2    Le'Veon Bell, PIT        RB       341.6
# 3     Alvin Kamara, NO        RB       320.4
# 4   Antonio Brown, PIT        WR       310.3

# %% [markdown]
# 9.Now go to this website to see what ESPN projected the player rankings to be BEFORE the season had started:
#
# http://www.espn.com/fantasy/football/story/_/page/17RanksPreseason200PPR/2017-fantasy-football-ppr-rankings-top-200
#
# We have also stored this locally as "fftprojections.htm". Use pd.read_html to read this data in.

# %% [markdown]
# 10.Save just the Player/Position/Team column to a dataframe called "df2". Rename the column "player".

# %%
table2 = pd.read_html('data/fftprojections.htm')
#table2 = pd.read_html('http://www.espn.com/fantasy/football/story/_/page/17RanksPreseason200PPR/2017-fantasy-football-ppr-rankings-top-200')
df2=table2[1]

# %%
df2 = df2[['Player/Position/Team']]
df2 = df2.rename(index=str, columns={'Player/Position/Team': 'player'})
df2.head()
# Out:
#                           player
# 0      1. David Johnson, RB, ARI
# 1       2. Le'Veon Bell, RB, PIT
# 2      3. Antonio Brown, WR, PIT
# 3    4. Ezekiel Elliott, RB, DAL
# 4  5. Odell Beckham Jr., WR, NYG

# %% [markdown]
# 11.We want to merge these two data frames. In order to do this, we need the player names to match up exactly. Update the "df2" data frame above to include only the player names and teams.

# %%
df2['player'] = [' '.join(player.split()[1:-2])+' '+player.split()[-1] for player in df2['player'] ]
df2.head()
# Out:
#                    player
# 0      David Johnson, ARI
# 1       Le'Veon Bell, PIT
# 2      Antonio Brown, PIT
# 3    Ezekiel Elliott, DAL
# 4  Odell Beckham Jr., NYG

# %% [markdown]
# 12.We'll want to create another column for what ESPN projected their ranking to be. Luckily, since they are in order, an index of 0 correponds to a ranking of 1, an index of 1 corresponds to a ranking of 2, etc. We can use the index and a list comprehension to create a ranking column:

# %%
df2['ranking'] = [int(x)+1 for x in df2.index]
df2.head()
# Out:
#                    player  ranking
# 0      David Johnson, ARI        1
# 1       Le'Veon Bell, PIT        2
# 2      Antonio Brown, PIT        3
# 3    Ezekiel Elliott, DAL        4
# 4  Odell Beckham Jr., NYG        5

# %% [markdown]
# 13.Okay, we are ready to merge these two dataframes. We'll use "inner" to denote that we only want to consider players that are in BOTH dataframes and we'll use "on=player" to denote that we want to merge the dataframes based on the player column.

# %%
results = pd.merge(df1, df2, how='inner', on = ['player'])
results.head()
# Out:
#                  player positions 2017 points  ranking
# 0   Russell Wilson, SEA        QB       347.9       79
# 1     Le'Veon Bell, PIT        RB       341.6        2
# 2      Alvin Kamara, NO        RB       320.4      152
# 3    Antonio Brown, PIT        WR       310.3        3
# 4  DeAndre Hopkins, HOU        WR       309.8       28

# %% [markdown]
# 14.Drop any rows that have any missing values. There might not be, but perform this operation just in case.

# %%
results = results.dropna(how = 'any')

# %% [markdown]
# 15.View all of the column data types using one command.

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 0 to 120
# Data columns (total 4 columns):
# player         121 non-null object
# positions      121 non-null object
# 2017 points    121 non-null object
# ranking        121 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# 16.Change the data type of 2017 points to a float.

# %%
results['2017 points'] = results['2017 points'].astype(float)

# %% [markdown]
# 17.Plot ESPN ranking on the x-axis versus 2017 points scored on the y-axis. Label your axes.

# %%
plt.plot(results['ranking'], results['2017 points'], '.')
plt.xlabel('espn ranking')
plt.ylabel('fantasy points')

# %% [markdown]
# 18.Is there a downward trend? Why does this make sense?

# %%
#because a ranking of 1 corresponds to the most projected points

# %% [markdown]
# 19.We can create a line of best fit:

# %%
import numpy as np

x = results['ranking']
y = results['2017 points']
fit = np.polyfit(x, y,1)
fit_fn = np.poly1d(fit) 
plt.plot(x, y,'.', x, fit_fn(x))
# Out:
# [<matplotlib.lines.Line2D at 0x107448048>,
#  <matplotlib.lines.Line2D at 0x107448240>]

# %% [markdown]
# 20.Print the slope and intercept of the line.

# %%
m, b = np.polyfit(x,y,1)
print(m,b)
# Out:
# -0.5734477697425076 213.67259031171207

# %% [markdown]
# 21.Create another column in the results dataframe called "predicted points" that lists the predicted points from the line of best fit for each player. Note: you can do this in one line. Don't use a loop.

# %%
results['predicted points'] = fit_fn(results['ranking'])

# %% [markdown]
# 22.Create another column called "residual" that lists the difference between the actual 2017 points and the predicted ESPN points.

# %%
results['residual'] = results['2017 points'] - results['predicted points']

# %% [markdown]
# 23.Sort the dataframe by residual from lowest to highest to see the most overrated players.

# %%
results.sort_values(by = 'residual', ascending = True).head()
# Out:
#                  player positions  2017 points  ranking  predicted points  \
# 114  David Johnson, ARI        RB         13.0        1        213.099143
# 118    Andrew Luck, IND        QB          0.0      116        147.152649
# 117    Kevin White, CHI        WR          2.6      117        146.579201
# 116   Tyler Eifert, CIN        TE          8.6      108        151.740231
# 109  Terrance West, BAL        RB         28.1       76        170.090560
#
#        residual
# 114 -200.099143
# 118 -147.152649
# 117 -143.979201
# 116 -143.140231
# 109 -141.990560

# %% [markdown]
# 24.R-squared is a measure of how well your model fits your data. Use the function below to calculate R-squared.

# %%
def rsquared(x, y, y_predicted):                   
    ybar = np.sum(y)/len(y)          
    ssreg = np.sum((y_predicted-ybar)**2)  
    sstot = np.sum((y - ybar)**2)  
    return ssreg / sstot

rsquared(results['ranking'], 
         results['2017 points'], 
         results['predicted points'])
# Out:
# 0.15948049574772416

# %% [markdown]
# 25.That R-Squared was pretty low. Let's try to do better.
#
# Up until now, you've only been able to create predictive models with numerical variables (e.g. rankings, points, etc.) However, we can also create regression models using categorical variables (such as football position!) Very exciting.
#
# In addition, up until now, you have probably only calculated a linear regression line when you have a single input variable. Today, we'll use multiple linear regression (where the input will be a matrix instead of a single vector).
#
# Our goal will be to use ESPN rankings (numerical) AND player position (categorical) to predict their fantasy points.
#
# Step 1: Create a new dataframe from the results dataframe called onehot that includes just the positions and ranking columns. (I'll explain why it's called onehot in a minute).

# %%
onehot = results[['ranking','positions']]
onehot.head()
# Out:
#    ranking positions
# 0       79        QB
# 1        2        RB
# 2      152        RB
# 3        3        WR
# 4       28        WR

# %% [markdown]
# 26.Now, a major step towards performing regression when there are categorical variables involved is first creating a matrix (called a one-hot matrix) where each position corresponds to a different column in the matrix. For example, if a player is a QB, he'll have a 1 in the QB column and a 0 in all of the others.
#
# We can do this using a built-in pandas function called get_dummies.
#
# Run the following code.

# %%
positions = pd.get_dummies(results['positions'])
onehot = onehot.drop('positions', axis = 1)
onehot = onehot.join(positions)
onehot.head()
# Out:
#    ranking  QB  RB  TE  WR
# 0       79   1   0   0   0
# 1        2   0   1   0   0
# 2      152   0   1   0   0
# 3        3   0   0   0   1
# 4       28   0   0   0   1

# %% [markdown]
# 27.Okay. Our input is going to be this matrix and our output is going to be the 2017 points. We'll need to have the scikit-learn package in order to use the the multiple linear regression model. scikit-learn is the most popular package for maching learning algorithms using Python. So exciting!!!
#
# Try running the cell below. If it doesn't work, try downloading the scikit-learn package by typing into your terminal this:
#
# pip install -U scikit-learn
#
# or this:
#
# conda install -c anaconda scikit-learn

# %%
from sklearn.linear_model import LinearRegression

X = onehot
y = results['2017 points']

clf = LinearRegression()
clf.fit(X, y)
clf.predict(X)
print('R-squared', clf.score(X,y))
# Out:
# R-squared 0.31478042460841704
# /Users/shareshianl/anaconda/lib/python3.6/site-packages/scipy/linalg/basic.py:1018: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %% [markdown]
# 28.Wow! Our R-squared doubled when we incorporated the player position into our input. Let's visualize what is going on with this multiple linear regression by creating the following plot below:

# %%
#Let's break things down by position:
quarterbacks = results[results['positions'] == 'QB']
runningbacks = results[results['positions'] == 'RB']
receivers = results[results['positions'] == 'WR']
tightends = results[results['positions'] == 'TE']

fig, ax = plt.subplots(figsize=(7,7))

ax.scatter(quarterbacks.ranking, quarterbacks['2017 points'],  color='blue', label='qb')
ax.scatter(runningbacks.ranking, runningbacks['2017 points'],  color='red', label='rb')
ax.scatter(receivers.ranking, receivers['2017 points'],  color='yellow', label = 'wr')
ax.scatter(tightends.ranking, tightends['2017 points'],  color='green', label = 'te')

ax.plot(X.ranking, clf.predict(X), 'k.', label = 'predictions')
ax.set_xlabel('ESPN projected pre-season player ranking 2017')
ax.set_ylabel('Total ESPN Fantasy Points that player scored in 2017')
ax.set_title('Position matters!')
ax.legend(loc='best')

# %% [markdown]
# 29.Explain in your own words why your multiple linear regression model is plotting the black dots in the manner that you see above.

# %%
#different linear lines for different positions

# %%
try:
    print(5/0)
except ZeroDivisionError as error:
    print(error)
    print('The linux_interaction() function was not executed')
# Out:
# division by zero
# The linux_interaction() function was not executed

# %% [markdown]
# Note: You've just explored the very beginnings of using Python to perform machine learning! Machine learning is a pretty ill defined term, but according to Wikipedia, "Machine learning explores the construction and study of algorithms that can learn from and make predictions on data."
#
# You have just learned the multiple linear regression sci-kit learn method. There are many MUCH better methods (RidgeCV, GradientBoostingRegressor, etc.)
#
# There are also better measures for how well a model does. (The adjusted R-squared measure is MUCH better than the R-squared measure.)
#
# In addition, we just committed the cardinal sin of data science in the above example, which is to use our entire dataset to train our model. In practice, we should have used just a subset of the player data to train our model (i.e., to calculate the line of best fit) and then we should have calculated how well our model did at predicting the test set values (the players that we didn't include in our training model).
#
# To learn more, this is a great first tutorial on how to use sci-kit learn for machine learning:
#
# https://www.datacamp.com/community/tutorials/machine-learning-python
#
# More docs are here:
#
# http://scikit-learn.org/stable/tutorial/basic/tutorial.html
#
# And Andrew Ng's online Machine Learning course is famous:
#
# https://www.coursera.org/learn/machine-learning
